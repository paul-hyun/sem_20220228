# %% [markdown]
# # Env

# %%
# imports
import argparse
import os
import random
import shutil
import json
import zipfile
import math
import copy
import collections
import re

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# import sentencepiece as spm
import tensorflow as tf
import tensorflow.keras.backend as K

from tqdm.notebook import tqdm, trange

# %%
# 환경 설정
args = {
    # random seed value
    "seed": 1234
}
args = argparse.Namespace(**args)

print(args)
# Out:
# Namespace(seed=1234)

# %%
# random seed 설정
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

# %% [markdown]
# # Softmax & cross entropy

# %%
x = np.array([0.9, 1.2, -0.4])
x

# %%
exp_x = np.exp(x)
exp_x

# %%
sum_x = np.sum(exp_x)
sum_x

# %%
np.sum(y_pred)

# %% [markdown]
# # TF Softmax

# %%
tf.nn.softmax(x)

# %% [markdown]
# # 실습
# - np.random.randn 함수를 이용해 (10, 4)의 랜덤값을 생성하고 numpy를 이용해 확률분포로 변환하세요.
# - np.random.randn 함수를 이용해 (10, 5)의 랜덤값을 생성하고 tf를 이용해 확률분포로 변환하세요.
